# %%
#Importin libraries
from ultralytics import YOLO

# %%
my_model= YOLO("yolo26n.pt")

predict = my_model("oscar.jpg", show = True)
# Out:
# image 1/1 /Users/mouad_farhi/Desktop/Projects/Football analyste/oscar.jpg: 640x384 1 dog, 1 bowl, 19.0ms
# Speed: 1.0ms preprocess, 19.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 384)
